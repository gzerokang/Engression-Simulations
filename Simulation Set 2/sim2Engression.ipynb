# %% [markdown]
# ## Engression

# %%
## an example with the original model

from EngressionSim2 import *

N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "log"
noise_dist = "gaussian"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


results1 = run_engression_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

engression_beta_estimates = results1['weight_estimates']
beta_mean_engression = engression_beta_estimates.mean(axis=0) 
print('Engression weight mean estimate:', beta_mean_engression)

# %%
## an example with the model using sparsity constrains

from EngressionSim2AddSparsity import *  

N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "log"
noise_dist = "gaussian"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
l1_lambda = 1

results1_sparse = run_engression_simulations_sparsity(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr, l1_lambda=l1_lambda
)

engression_beta_estimates_sparse = results1_sparse['weight_estimates']
beta_mean_engression_sparse = engression_beta_estimates_sparse.mean(axis=0) 
print('Engression weight mean estimate:', beta_mean_engression_sparse)

# %%
## an example with the model using dropout layer

from EngressionSim2AddDropout import *  

N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "log"
noise_dist = "gaussian"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dropout_prop = 0.2

results1_dropout = run_engression_simulations_dropout(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr, dropout_prop=dropout_prop
)

engression_beta_estimates_dropout = results1_dropout['weight_estimates']
beta_mean_engression_dropout = engression_beta_estimates_dropout.mean(axis=0) 
print('Engression weight mean estimate:', beta_mean_engression_dropout)

# %% [markdown]
# ## Run Engression simulations

# %%
from EngressionSim2 import *
## from EngressionSim2-AddSparsity import *  ## uncomment if use sparsity
## from EngressionSim2-AddDropout import *   ## uncomment if use dropout

# %%
## an example of adding sparsity 
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "log"
noise_dist = "gaussian"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
l1_lambda = 1

results1 = run_engression_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr, l1_lambda=l1_lambda
)

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "log"
noise_dist = "uniform"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


results2 = run_engression_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "softplus"
noise_dist = "gaussian"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results3 = run_engression_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "softplus"
noise_dist = "uniform"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results4 = run_engression_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "square"
noise_dist = "gaussian"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results5 = run_engression_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "square"
noise_dist = "uniform"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results6 = run_engression_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "cubic"
noise_dist = "gaussian"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results7 = run_engression_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "cubic"
noise_dist = "uniform"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results8 = run_engression_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
np.savez("simresults2_engression.npz", results_log1=results1, results_log2=results2,
         results_softplus1=results3,results_softplus2=results4,
         results_square1=results5,results_square2=results6,
         results_cubic1=results7,results_cubic2=results8)
