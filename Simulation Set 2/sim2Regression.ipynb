# %% [markdown]
# ## Regression

# %%
from RegressionSim2 import *

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "log"
noise_dist = "gaussian"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results1 = run_compare_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "log"
noise_dist = "uniform"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


results2 = run_compare_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "softplus"
noise_dist = "gaussian"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results3 = run_compare_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "softplus"
noise_dist = "uniform"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results4 = run_compare_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "square"
noise_dist = "gaussian"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results5 = run_compare_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "square"
noise_dist = "uniform"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results6 = run_compare_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "cubic"
noise_dist = "gaussian"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results7 = run_compare_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
N_sim = 20
x_min = -0.55
x_max = 1.64
x_lower = 0
x_upper = 0.55
true_function = "cubic"
noise_dist = "uniform"
noise_correlation = 0
num_epochs = 200
n_train=10000
num_points = 1000
noise_std = 0.1
lr = 0.005
batch_size=5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

results8 = run_compare_simulations(
    N_sim=N_sim, x_min=x_min, x_max=x_max,
    x_lower=x_lower,x_upper=x_upper,
    true_function=true_function,
    n_train=n_train,
    noise_dist=noise_dist,
    noise_corr=noise_correlation,
    num_epochs=num_epochs,
    num_points=num_points,
    noise_std = noise_std,
    batch_size = batch_size,
    device=device,lr=lr
)

# %%
np.savez("simresults2_engression.npz", results_log1=results1, results_log2=results2,
         results_softplus1=results3,results_softplus2=results4,
         results_square1=results5,results_square2=results6,
         results_cubic1=results7,results_cubic2=results8)
